# %%
import pandas as pd
import numpy as np
import requests
import csv
from bs4 import BeautifulSoup

# %% [markdown]
# The function get_10_K() below takes 2 parameters.
#         # >"year" is the year of 10-K report.
#         # >"start" is the corresponding iterator that iterates through 1->the number of 10-K reports

# %%
def get_10_K(start,year="2018"):
# initiate the url
    start=str(start)
    url_1="https://www.sec.gov/cgi-bin/srch-edgar?text=%2210-K%22%20NOT%20%22NT%22&start="+start+"&count=1&first="+year+"&last="+year

#Step 1: access the search website
    response = requests.get(url_1)
    if response.status_code == 200:
        pass
    else:
        print("Failure")

#Step 2: Print and Find the 10K report tag
    results_page = BeautifulSoup(response.content,'lxml')
    #print(results_page.prettify())

    td_tag = results_page.find('td',align="left",valign="top")

# Generate the URL for next step.
    CompanyName=td_tag.find("a").get_text()
    url_2=td_tag.find("a").get("href")
    url_2="https://www.sec.gov"+url_2

# Step 3: access the index file
    response_2 = requests.get(url_2)
    if response_2.status_code == 200:
        pass
    else:
        print("Failure")
# Step 4: genreate the url of the 10-K report: url_3
    results_page_2 = BeautifulSoup(response_2.content,'lxml')
    #print(results_page_2.prettify())

    all_td_tags_2 = results_page_2.find_all('td',scope="row")

    url_3=all_td_tags_2[2].find("a").get("href")
    url_3="https://www.sec.gov"+url_3

    response_3=requests.get(url_3)
    if response_3.status_code == 200:
        pass
    else:
        print("Failure")

    results_page_3 = BeautifulSoup(response_3.content,'lxml')
    #print(results_page.prettify())
# Step 5: search for and  gather the text file( assume all useful information is embedded in tab <p> )
    all_font_tags = results_page_3.find_all('p')

    text=""
    for tag in all_font_tags:
        text=text+" "+tag.get_text()

# Step 6: If fails, try assumption: tab <font> )
    if len(text)<5000:
        all_font_tags = results_page_3.find_all('font')

        text=""
        for tag in all_font_tags:
            text=text+" "+tag.get_text()
# Step 7: If still fails, skip the document-writing part and print error message)   
    flag=(len(text)<8000)
            
    if not flag:
        CompanyName=CompanyName.replace("/","_")
        CompanyName=CompanyName.replace("\\","_")
        with open(CompanyName+'.txt', 'w',encoding="utf-8") as f:  
            f.write(text)
            f.close()
    else:
        print("Company Name:",CompanyName)
        print("Text Length",len(text))
        print("link to 10-K",url_3)
    return flag

# %% [markdown]
# Follow the template below to write all 10-K reports!

# %%
for start in range(1,21):
    flag=get_10_K(start)
    if flag:
        print(start,"Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# Company Name: 1ST CONSTITUTION BANCORP
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1141807/000114180718000005/fccy-20171231x10k.htm
# 5 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
for start in range(21,201):
    flag=get_10_K(start)
    if flag:
        print(start,"Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# Company Name: ABCO Energy, Inc.
# Text Length 2972
# link to 10-K https://www.sec.gov/Archives/edgar/data/1300938/000118518518000715/abcoenergy10k123117.htm
# 33 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Acacia Diversified Holdings, Inc.
# Text Length 3204
# link to 10-K https://www.sec.gov/Archives/edgar/data/1001463/000118518518000573/acaciadiversified10k123117.htm
# 42 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: ACCESS POWER INC
# Text Length 0
# link to 10-K https://www.sec.gov/Archives/edgar/data/1041588/000104158818000040/accr123115k.txt
# 52 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name
Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: FS Investment Corp II
# Text Length 4344
# link to 10-K https://www.sec.gov/Archives/edgar/data/1525759/000114420418013804/tv487941-10k.htm
# 2673 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: FS Investment Corp IV
# Text Length 7177
# link to 10-K https://www.sec.gov/Archives/edgar/data/1637417/000114420418013896/tv488029-10k.htm
# 2675 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: FULLNET COMMUNICATIONS INC
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1092570/000137647418000068/fulo-20171231.htm
# 2688 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: G III APPAREL GROUP LTD /DE/
# Text Length 2708
# link to 10-K https://www.sec.gov/Archives/edgar/data/821002/000114420418018565/tv489439-10k.htm
# 2700 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Geospatial Corp
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1011395/000137647418000092/gsph-20171231.htm
# 2777 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GIFA, INC.
# Text Length 5484
# link to 10-K https://www.sec.gov/Archives/edgar/data/1445883/000109690618000420/gifa.htm
# 2788 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Global Arena Holding, Inc.
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1138724/000101489718000034/gahc-20171231.htm
# 2803 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Go Eco Group
# Text Length 1958
# link to 10-K https://www.sec.gov/Archives/edgar/data/1503161/000172171618000012/libe10k-09302017.htm
# 2848 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Gold Standard Mining Co
# Text Length 1323
# link to 10-K https://www.sec.gov/Archives/edgar/data/1705445/000121465918002508/gs32818010k.htm
# 2854 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GREEN HYGIENICS HOLDINGS INC.
# Text Length 1367
# link to 10-K https://www.sec.gov/Archives/edgar/data/1443388/000116552718000219/g8633a.htm
# 2921 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GREEN HYGIENICS HOLDINGS INC.
# Text Length 1011
# link to 10-K https://www.sec.gov/Archives/edgar/data/1443388/000116552718000133/g8575.htm
# 2922 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GREEN HYGIENICS HOLDINGS INC.
# Text Length 951
# link to 10-K https://www.sec.gov/Archives/edgar/data/1443388/000116552718000119/g8571.htm
# 2923 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GREENE COUNTY BANCORP INC
# Text Length 3956
# link to 10-K https://www.sec.gov/Archives/edgar/data/1070524/000114036118038309/form10k.htm
# 2931 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: GSV Capital Corp.
# Text Length 6557
# link to 10-K https://www.sec.gov/Archives/edgar/data/1509470/000114420418015279/tv488445-10k.htm
# 2987 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Hartford Great Health Corp.
# Text Length 6294
# link to 10-K https://www.sec.gov/Archives/edgar/data/1482554/000107997318000628/hghc_10k-073118.htm
# 3054 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: HAVERTY FURNITURE COMPANIES INC
# Text Length 3283
# link to 10-K https://www.sec.gov/Archives/edgar/data/216085/000021608518000011/hvt10k123117.htm
# 3062 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1f0320844596> in <module>
#       1 for start in range(2001,4001):
# ----> 2     flag=get_10_K(start)
#       3     if flag:
#       4         print(start,"Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
#
# <ipython-input-3-cc320bd25a6b> in get_10_K(start, year)
#      38     url_3="https://www.sec.gov"+url_3
#      39
# ---> 40     response_3=requests.get(url_3)
#      41     if response_3.status_code == 200:
#      42         pass
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     319     if ca_certs or ca_cert_dir:
#     320         try:
# --> 321             context.load_verify_locations(ca_certs, ca_cert_dir)
#     322         except IOError as e:  # Platform-specific: Python 2.7
#     323             raise SSLError(e)
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in load_verify_locations(self, cafile, capath, cadata)
#     426         if capath is not None:
#     427             capath = capath.encode('utf-8')
# --> 428         self._ctx.load_verify_locations(cafile, capath)
#     429         if cadata is not None:
#     430             self._ctx.load_verify_locations(BytesIO(cadata))
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in load_verify_locations(self, cafile, capath)
#     776
#     777         load_result = _lib.SSL_CTX_load_verify_locations(
# --> 778             self._context, cafile, capath
#     779         )
#     780         if not load_result:
#
# KeyboardInterrupt:

# %%
for start in range(3063,4001):
    flag=get_10_K(start)
    if flag:
        print(start,"Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# Company Name: HEICO CORP
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/46619/000004661918000117/hei1031201810k.htm
# 3095 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Heron Street Acquisition Corp
# Text Length 0
# link to 10-K https://www.sec.gov/Archives/edgar/data/1681312/000102143218000124/heronstreet10k2017.txt
# 3122 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Home Treasure Finders, Inc.
# Text Length 4460
# link to 10-K https://www.sec.gov/Archives/edgar/data/1527102/000107997418000177/htmf10k12312017.htm
# 3176 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: HomeStreet, Inc.
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1518715/000151871518000095/hmst-20171231x10k.htm
# 3179 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: HOOKER FURNITURE CORP
# Text Length 7826
# link to 10-K https://www.sec.gov/Archives/edgar/data/1077688/000118518518000692/hookerfurniture10k012818.htm
# 3196 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: HORACE MANN EDUCATORS CORP /DE/
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/850141/000162828018002567/a201710k.htm
# 3201 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Hubper Group Inc.
# Text Length 0
# link to 10-K https://www.sec.gov/Archives/edgar/data/1709560/000102143218000106/callagrovehubper10kv1.txt
# 3233 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Hughes Satellite Systems Corp
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1533758/000153375818000004/hssc12311710kdocument.htm
# 3239 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: I-ON Communications Corp.
# Text Length 7526
# link to 10-K https://www.sec.gov/Archives/edgar/data/1580490/000114036118027878/form10k.htm
# 3282 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: i3 Verticals, Inc.
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1728688/000172868818000027/iiiv-20180930.htm
# 3283 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: Incoming, Inc.
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/1423325/000144586618000409/icnn-20171231.htm
# 3359 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: INDEPENDENCE HOLDING CO
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/701869/000070186918000019/ihc-20171231.htm
# 3362 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: INDEPENDENT BANK CORP /MI/
# Text Length 4381
# link to 10-K https://www.sec.gov/Archives/edgar/data/39311/000114036118012451/h10050825x1_10k.htm
# 3365 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Company Name: INDUSTRIAL SERVICES OF AMERICA INC
# Text Length 5988
# link to 10-K https://www.sec.gov/ix?doc=/Archives/edgar/data/4187/000089710118000301/idsa-20171231.htm
# 3373 Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0b9045c722af> in <module>
#       1 for start in range(3063,4001):
# ----> 2     flag=get_10_K(start)
#       3     if flag:
#       4         print(start,"Fail!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
#
# <ipython-input-3-cc320bd25a6b> in get_10_K(start, year)
#      44         print("Failure")
#      45
# ---> 46     results_page_3 = BeautifulSoup(response_3.content,'lxml')
#      47     #print(results_page.prettify())
#      48 # Step 5: search for and  gather the text file( assume all useful information is embedded in tab <p> )
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     280             self.reset()
#     281             try:
# --> 282                 self._feed()
#     283                 break
#     284             except ParserRejectedMarkup:
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     341         self.builder.reset()
#     342
# --> 343         self.builder.feed(self.markup)
#     344         # Close out any unfinished strings and close all the open tags.
#     345         self.endData()
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_lxml.py in feed(self, markup)
#     253             self.parser = self.parser_for(encoding)
#     254             self.parser.feed(markup)
# --> 255             self.parser.close()
#     256         except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#     257             raise ParserRejectedMarkup(str(e))
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.close()
#
# src/lxml/parser.pxi in lxml.etree._FeedParser.close()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/parsertarget.pxi in lxml.etree._TargetParserContext._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/saxparser.pxi in lxml.etree._handleSaxEndNoNs()
#
# src/lxml/parsertarget.pxi in lxml.etree._PythonSaxParserTarget._handleSaxEnd()
#
# ~\Anaconda3\lib\site-packages\bs4\builder\_lxml.py in end(self, name)
#     206                     nsprefix = inverted_nsmap[namespace]
#     207                     break
# --> 208         self.soup.handle_endtag(name, nsprefix)
#     209         if len(self.nsmaps) > 1:
#     210             # This tag, or one of its parents, introduced a namespace
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in handle_endtag(self, name, nsprefix)
#     530         #print "End tag: " + name
#     531         self.endData()
# --> 532         self._popToTag(name, nsprefix)
#     533
#     534     def handle_data(self, data):
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in _popToTag(self, name, nsprefix, inclusivePop)
#     494             if (name == t.name and nsprefix == t.prefix):
#     495                 if inclusivePop:
# --> 496                     most_recently_popped = self.popTag()
#     497                 break
#     498             most_recently_popped = self.popTag()
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in popTag(self)
#     372         raise NotImplementedError("BeautifulSoup objects don't support insert_after().")
#     373
# --> 374     def popTag(self):
#     375         tag = self.tagStack.pop()
#     376         if self.preserve_whitespace_tag_stack and tag == self.preserve_whitespace_tag_stack[-1]:
#
# KeyboardInterrupt:

# %%
3374
