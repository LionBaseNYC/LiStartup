# %% [markdown]
# #### Imports

# %%
import string
from collections import Counter
import os
import pickle

import numpy as np
import pandas as pd

#
# Domain specific libraries to handle text
#
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %% [markdown]
# #### Fist time Use

# %% [markdown]
# This notebook downloads some data, and generates some pre-processed files we will neede later.
#
# Set the `fist_time` flag below to True **once**, after that, it will be faster to run the notebook
# with the flag set to false.

# %%
first_time=True

# %% [markdown]
# #### Data Directories

# %% [markdown]
# You must download the [Reuters 50 from this link](https://archive.ics.uci.edu/ml/datasets/Reuter_50_50), unzip it and save it to the `raw` data directory so that data is organized as per the variables below.

# %%
raw_data_dir="Train_2018"   # original data set used for training
test_dir    ="Test_2018"  # original test data set
data_dir    ="Intermediate_Result_2018"  # directory to save intermediate results
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
# This only needs to be run once, to get access to data used by nltk
if first_time:
    import nltk
    nltk.download('punkt') # punctuation items required by tokenizer
    nltk.download('stopwords') # for stop words
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Heyang
# [nltk_data]     Huang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Heyang
# [nltk_data]     Huang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def stem_tokenizer(text):
    return [porter_stemmer.stem(token) for token in word_tokenize(text.lower().replace("'"," "))]

# %%
punctuation=list(string.punctuation)
stop=stopwords.words("english")+punctuation+['``',"''"]

# %% [markdown]
# ## Read in the 10-K

# %%
documents=pd.DataFrame()
documents["filename"]=os.listdir("Train_2018")
companyName=np.array([])
companyPath=np.array([])
for txt in documents["filename"].values:
    new_cn=txt[:-4]
    new_path="Train_2018/"+txt
    companyName=np.append(companyName,new_cn)
    companyPath=np.append(companyPath,new_path)
documents["companyName"]=companyName
documents["companyPath"]=companyPath

# %%
documents
# Out:
#                                                filename  \
# 0                        CHIPOTLE MEXICAN GRILL INC.txt
# 1               CHOICE HOTELS INTERNATIONAL INC _DE.txt
# 2                  CHOICEONE FINANCIAL SERVICES INC.txt
# 3                          CHRISTOPHER & BANKS CORP.txt
# 4                                   ChromaDex Corp..txt
# 5                                           CHS INC.txt
# 6                                         Chubb Ltd.txt
# 7                  CHUGACH ELECTRIC ASSOCIATION INC.txt
# 8                       CHURCH & DWIGHT CO INC _DE_.txt
# 9                               CHURCHILL DOWNS Inc.txt
# 10                            CHUY'S HOLDINGS, INC..txt
# 11                                       CICERO INC.txt
# 12                        Cidara Therapeutics, Inc..txt
# 13                                       CIENA CORP.txt
# 14                                       CIGNA CORP.txt
# 15                        CIM Commercial Trust Corp.txt
# 16                                CIMAREX ENERGY CO.txt
# 17                                    CIMPRESS N.V..txt
# 18                               Cincinnati Bancorp.txt
# 19                              CINCINNATI BELL INC.txt
# 20                        CINCINNATI FINANCIAL CORP.txt
# 21                                   Cinedigm Corp..txt
# 22                          Cinemark Holdings, Inc..txt
# 23                             CINEMARK USA INC _TX.txt
# 24                               Ciner Resources LP.txt
# 25                                      CINTAS CORP.txt
# 26                             CION Investment Corp.txt
# 27                                   CIPHERLOC Corp.txt
# 28                         CIRCOR INTERNATIONAL INC.txt
# 29                                 CIRRUS LOGIC INC.txt
# ...                                                 ...
# 4725                     WIRELESS TELECOM GROUP INC.txt
# 4726                    WISCONSIN ELECTRIC POWER CO.txt
# 4727                     WISCONSIN POWER & LIGHT CO.txt
# 4728                  WISCONSIN PUBLIC SERVICE CORP.txt
# 4729     WisdomTree Continuous Commodity Index Fund.txt
# 4730  WisdomTree Continuous Commodity Index Master F...
# 4731                   WisdomTree Investments, Inc..txt
# 4732                             Wizard World, Inc..txt
# 4733                              Wize Pharma, Inc..txt
# 4734                          WMI Liquidating Trust.txt
# 4735                                     WMIH CORP..txt
# 4736                   Wolverine Technologies Corp..txt
# 4737                  WOLVERINE WORLD WIDE INC _DE_.txt
# 4738                                 Woodward, Inc..txt
# 4739                                  Workday, Inc..txt
# 4740                           Workhorse Group Inc..txt
# 4741                          WORLD ACCEPTANCE CORP.txt
# 4742                               World Gold Trust.txt
# 4743             World Monitor Trust III - Series J.txt
# 4744               WORLD WRESTLING ENTERTAINMENTINC.txt
# 4745                         WORLDNET INC OF NEVADA.txt
# 4746                                 Worldpay, Inc..txt
# 4747                                     WORLDS INC.txt
# 4748             Worldwide Specialty Chemicals Inc..txt
# 4749                     WORTHINGTON INDUSTRIES INC.txt
# 4750            WOUND MANAGEMENT TECHNOLOGIES, INC..txt
# 4751                               WPX ENERGY, INC..txt
# 4752                        WRAP TECHNOLOGIES, INC..txt
# 4753                      Wright Medical Group N.V..txt
# 4754                            WSFS FINANCIAL CORP.txt
#
#                                             companyName  \
# 0                            CHIPOTLE MEXICAN GRILL INC
# 1                   CHOICE HOTELS INTERNATIONAL INC _DE
# 2                      CHOICEONE FINANCIAL SERVICES INC
# 3                              CHRISTOPHER & BANKS CORP
# 4                                       ChromaDex Corp.
# 5                                               CHS INC
# 6                                             Chubb Ltd
# 7                      CHUGACH ELECTRIC ASSOCIATION INC
# 8                           CHURCH & DWIGHT CO INC _DE_
# 9                                   CHURCHILL DOWNS Inc
# 10                                CHUY'S HOLDINGS, INC.
# 11                                           CICERO INC
# 12                            Cidara Therapeutics, Inc.
# 13                                           CIENA CORP
# 14                                           CIGNA CORP
# 15                            CIM Commercial Trust Corp
# 16                                    CIMAREX ENERGY CO
# 17                                        CIMPRESS N.V.
# 18                                   Cincinnati Bancorp
# 19                                  CINCINNATI BELL INC
# 20                            CINCINNATI FINANCIAL CORP
# 21                                       Cinedigm Corp.
# 22                              Cinemark Holdings, Inc.
# 23                                 CINEMARK USA INC _TX
# 24                                   Ciner Resources LP
# 25                                          CINTAS CORP
# 26                                 CION Investment Corp
# 27                                       CIPHERLOC Corp
# 28                             CIRCOR INTERNATIONAL INC
# 29                                     CIRRUS LOGIC INC
# ...                                                 ...
# 4725                         WIRELESS TELECOM GROUP INC
# 4726                        WISCONSIN ELECTRIC POWER CO
# 4727                         WISCONSIN POWER & LIGHT CO
# 4728                      WISCONSIN PUBLIC SERVICE CORP
# 4729         WisdomTree Continuous Commodity Index Fund
# 4730  WisdomTree Continuous Commodity Index Master Fund
# 4731                       WisdomTree Investments, Inc.
# 4732                                 Wizard World, Inc.
# 4733                                  Wize Pharma, Inc.
# 4734                              WMI Liquidating Trust
# 4735                                         WMIH CORP.
# 4736                       Wolverine Technologies Corp.
# 4737                      WOLVERINE WORLD WIDE INC _DE_
# 4738                                     Woodward, Inc.
# 4739                                      Workday, Inc.
# 4740                               Workhorse Group Inc.
# 4741                              WORLD ACCEPTANCE CORP
# 4742                                   World Gold Trust
# 4743                 World Monitor Trust III - Series J
# 4744                   WORLD WRESTLING ENTERTAINMENTINC
# 4745                             WORLDNET INC OF NEVADA
# 4746                                     Worldpay, Inc.
# 4747                                         WORLDS INC
# 4748                 Worldwide Specialty Chemicals Inc.
# 4749                         WORTHINGTON INDUSTRIES INC
# 4750                WOUND MANAGEMENT TECHNOLOGIES, INC.
# 4751                                   WPX ENERGY, INC.
# 4752                            WRAP TECHNOLOGIES, INC.
# 4753                          Wright Medical Group N.V.
# 4754                                WSFS FINANCIAL CORP
#
#                                             companyPath
# 0             Train_2018/CHIPOTLE MEXICAN GRILL INC.txt
# 1     Train_2018/CHOICE HOTELS INTERNATIONAL INC _DE...
# 2       Train_2018/CHOICEONE FINANCIAL SERVICES INC.txt
# 3               Train_2018/CHRISTOPHER & BANKS CORP.txt
# 4                        Train_2018/ChromaDex Corp..txt
# 5                                Train_2018/CHS INC.txt
# 6                              Train_2018/Chubb Ltd.txt
# 7       Train_2018/CHUGACH ELECTRIC ASSOCIATION INC.txt
# 8            Train_2018/CHURCH & DWIGHT CO INC _DE_.txt
# 9                    Train_2018/CHURCHILL DOWNS Inc.txt
# 10                 Train_2018/CHUY'S HOLDINGS, INC..txt
# 11                            Train_2018/CICERO INC.txt
# 12             Train_2018/Cidara Therapeutics, Inc..txt
# 13                            Train_2018/CIENA CORP.txt
# 14                            Train_2018/CIGNA CORP.txt
# 15             Train_2018/CIM Commercial Trust Corp.txt
# 16                     Train_2018/CIMAREX ENERGY CO.txt
# 17                         Train_2018/CIMPRESS N.V..txt
# 18                    Train_2018/Cincinnati Bancorp.txt
# 19                   Train_2018/CINCINNATI BELL INC.txt
# 20             Train_2018/CINCINNATI FINANCIAL CORP.txt
# 21                        Train_2018/Cinedigm Corp..txt
# 22               Train_2018/Cinemark Holdings, Inc..txt
# 23                  Train_2018/CINEMARK USA INC _TX.txt
# 24                    Train_2018/Ciner Resources LP.txt
# 25                           Train_2018/CINTAS CORP.txt
# 26                  Train_2018/CION Investment Corp.txt
# 27                        Train_2018/CIPHERLOC Corp.txt
# 28              Train_2018/CIRCOR INTERNATIONAL INC.txt
# 29                      Train_2018/CIRRUS LOGIC INC.txt
# ...                                                 ...
# 4725          Train_2018/WIRELESS TELECOM GROUP INC.txt
# 4726         Train_2018/WISCONSIN ELECTRIC POWER CO.txt
# 4727          Train_2018/WISCONSIN POWER & LIGHT CO.txt
# 4728       Train_2018/WISCONSIN PUBLIC SERVICE CORP.txt
# 4729  Train_2018/WisdomTree Continuous Commodity Ind...
# 4730  Train_2018/WisdomTree Continuous Commodity Ind...
# 4731        Train_2018/WisdomTree Investments, Inc..txt
# 4732                  Train_2018/Wizard World, Inc..txt
# 4733                   Train_2018/Wize Pharma, Inc..txt
# 4734               Train_2018/WMI Liquidating Trust.txt
# 4735                          Train_2018/WMIH CORP..txt
# 4736        Train_2018/Wolverine Technologies Corp..txt
# 4737       Train_2018/WOLVERINE WORLD WIDE INC _DE_.txt
# 4738                      Train_2018/Woodward, Inc..txt
# 4739                       Train_2018/Workday, Inc..txt
# 4740                Train_2018/Workhorse Group Inc..txt
# 4741               Train_2018/WORLD ACCEPTANCE CORP.txt
# 4742                    Train_2018/World Gold Trust.txt
# 4743  Train_2018/World Monitor Trust III - Series J.txt
# 4744    Train_2018/WORLD WRESTLING ENTERTAINMENTINC.txt
# 4745              Train_2018/WORLDNET INC OF NEVADA.txt
# 4746                      Train_2018/Worldpay, Inc..txt
# 4747                          Train_2018/WORLDS INC.txt
# 4748  Train_2018/Worldwide Specialty Chemicals Inc..txt
# 4749          Train_2018/WORTHINGTON INDUSTRIES INC.txt
# 4750  Train_2018/WOUND MANAGEMENT TECHNOLOGIES, INC....
# 4751                    Train_2018/WPX ENERGY, INC..txt
# 4752             Train_2018/WRAP TECHNOLOGIES, INC..txt
# 4753           Train_2018/Wright Medical Group N.V..txt
# 4754                 Train_2018/WSFS FINANCIAL CORP.txt
#
# [4755 rows x 3 columns]

# %% [markdown]
# ## Initiate Vectorizers

# %%
countVectorizer=CountVectorizer(input="filename",tokenizer=stem_tokenizer,stop_words=stop)
tfidfVectorizer=TfidfVectorizer(min_df=1, max_df=0.9, stop_words=stop, decode_error='ignore')

# %%
# Fit the training and transform testing dataset
X_count=countVectorizer.fit_transform(documents["companyPath"])
X_tfidf=tfidfVectorizer.fit_transform(documents["companyPath"])

# %%
X_count_test=countVectorizer.transform(documents["companyPath"])
X_tfidf_test=tfidfVectorizer.transform(documents["companyPath"])

# %% [markdown]
# Save the temporary result

# %%
count_vectorizer_filename=   data_dir+"/count_vectorizer.p"
count_features_filename=   data_dir+"/count_features.p"
count_test_features_filename=data_dir+"/count_test_features.p"

# %%
tfidf_vectorizer_filename=data_dir+"/tfidf_vectorizer.p"
tfidf_features_filename=data_dir+"/tfidf_features.p"
tfidf_test_features_filename=data_dir+"/tfidf_test_features.p"

# %%
pickle.dump(countVectorizer, open( count_vectorizer_filename, "wb" ) )
pickle.dump(X_count,         open( count_features_filename, "wb" ) )
pickle.dump(X_count_test,    open( count_test_features_filename, "wb" ) )

pickle.dump(tfidfVectorizer, open( tfidf_vectorizer_filename, "wb" ) )
pickle.dump(X_tfidf,              open( tfidf_features_filename, "wb" ) )
pickle.dump(X_tfidf_test,         open( tfidf_test_features_filename, "wb" ) )
